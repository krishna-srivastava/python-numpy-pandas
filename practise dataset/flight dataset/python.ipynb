# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("flights")
# print(df.head())
# print(df.tail())
# print(df.info())
# print(df.shape)

# print(df.isnull().sum())

# Total passengers per year
years = df.groupby("year")["passengers"].sum()
print(years)

# Average passengers per month
monthly_avg = df.groupby("month")["passengers"].mean().round(2)
print(monthly_avg)

# Line plot (yearly trend)
sns.lineplot(x="year", y="passengers", data=df, estimator="sum")
plt.title("Total Passengers per Year")
plt.show()
# Out:
# year
# 1949    1520
# 1950    1676
# 1951    2042
# 1952    2364
# 1953    2700
# 1954    2867
# 1955    3408
# 1956    3939
# 1957    4421
# 1958    4572
# 1959    5140
# 1960    5714
# Name: passengers, dtype: int64
# month
# Jan    241.75
# Feb    235.00
# Mar    270.17
# Apr    267.08
# May    271.83
# Jun    311.67
# Jul    351.33
# Aug    351.08
# Sep    302.42
# Oct    266.58
# Nov    232.83
# Dec    261.83
# Name: passengers, dtype: float64
# C:\Users\Nikku\AppData\Local\Temp\ipykernel_11424\86488482.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   monthly_avg = df.groupby("month")["passengers"].mean().round(2)
